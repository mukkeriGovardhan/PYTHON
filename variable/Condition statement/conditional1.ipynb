# %% [markdown]
# 50 question and answer on conditional statemnt

# %%
# check if a number is even or odd
nums = int(input("Enter a number: "))
if nums % 2 == 0:
    print(f"{nums} is an even number.")
else:
    print(f"{nums} is an odd number.")
# Out:
# 7 is an odd number.

# %%
# . Check if a person is eligible to vote (age 18 or above)
age = int(input("Enter your age: "))
if age>18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# You are eligible to vote.

# %%
# . Determine if a given year is a leap year or not
year = int(input("Enter a year: "))
if (year % 400 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a leap year.")    
else:
    print(f"{year} is not a leap year.")
# Out:
# 2024 is not a leap year.

# %%
# Check if a number is positive, negative, or zero
nums = int(input("Enter a number: "))
if nums >0 :
    print(f"{nums} is a positive number.")
elif nums < 0:
    print(f"{nums} is a negative number.")  
else:
    print(f"{nums} is zero.")
# Out:
# 2 is a positive number.

# %%
# Write a program to find the greatest of two numbers
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
if num1 > num2:
    print(f"{num1} is the greatest.")
else:
    print(f"{num2} is the greatest.")
# Out:
# 34 is the greatest.

# %%
# Determine if a number is a multiple of 5
num = int(input("Enter a number: "))
if num % 5 == 0:
    print(f"{num} is a multiple of 5.") 
else:
    print(f"{num} is not a multiple of 5.")
# Out:
# 24 is not a multiple of 5.

# %%
# Check if a character is a vowel or consonant
char = input("Enter a character: ").lower()
if char in 'aeiou':
    print(f"{char} is a vowel.")
else:
    print(f"{char} is a consonant.")
# Out:
# w is a consonant.

# %%
#Determine if a person is eligible for a senior citizen discount (age 60+)
age = int(input("Enter your age: "))
if age >= 60:
    print("You are eligible for a senior citizen discount.")
else:
    print("You are not eligible for a senior citizen discount.")
# Out:
# You are not eligible for a senior citizen discount.

# %%
#Check if a number is a single-digit number
num = int(input("Enter a number: "))
if 0 <= num <= 9:
    print(f"{num} is a single-digit number.")   
else:    print(f"{num} is not a single-digit number.")
# Out:
# 2 is a single-digit number.

# %%
#. Print "Good Morning" if the time is before 12 PM, otherwise print "Good Afternoon"
hour = int(input("Enter the current hour (0-23): "))
if hour < 12:
    print("Good Morning")   
else:
    print("Good Afternoon")
# Out:
# Good Morning

# %%
#1. Check if a string is empty or not
string = input("Enter a string: ")
if not string:
    print("The string is  empty.")
else:
    print("The string is not empty.")
# Out:
# The string is  empty.

# %%
# Verify if a number is a perfect square
num = int(input("Enter a number: "))
if num >= 0:    
    sqrt = int(num ** 0.5)
    if sqrt * sqrt == num:
        print(f"{num} is a perfect square.")
    else:
        print(f"{num} is not a perfect square.")
# Out:
# 24 is not a perfect square.

# %%
# . Determine if a number is between 1 and 100
num = int(input("Enter a number: "))
if 1 <= num <= 100:
    print(f"{num} is between 1 and 100.")
else:
    print(f"{num} is not between 1 and 100.")
# Out:
# 199 is not between 1 and 100.

# %%
#Print "Weekend" if the day is Saturday or Sunday; otherwise, print "Weekday"
day = input("Enter the day of the week: ").lower()
if day in ['saturday', 'sunday']:
    print("Weekend")
else:
    print("Weekday")
# Out:
# Weekend

# %%
# . Find if a given number is exactly divisible by both 3 and 7
num = int(input("Enter a number: "))
if num % 3 == 0 and num % 7 == 0:
    print(f"{num} is exactly divisible by both 3 and 7.")
else:
    print(f"{num} is not exactly divisible by both 3 and 7.")
# Out:
# 23 is not exactly divisible by both 3 and 7.

# %%
# Check if the sum of two numbers is greater than 100
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))  
if num1 + num2 > 100:
    print(f"The sum of {num1} and {num2} is greater than 100.")
else:
    print(f"The sum of {num1} and {num2} is not greater than 100.")
# Out:
# The sum of 23 and 12 is not greater than 100.

# %%
# Check if a number is divisible by 2 but not by 3
num = int(input("Enter a number: "))
if num % 2 == 0 and num % 3 != 0:
    print(f"{num} is divisible by 2 but not by 3.")
else:    print(f"{num} is not divisible by 2 or it is divisible by 3.")
# Out:
# 6 is not divisible by 2 or it is divisible by 3.

# %%
# . Determine if a given alphabet is uppercase or lowercase

char = input("Enter a character: ")
if char.isupper():
    print(f"{char} is an uppercase letter.")
else:    
    print(f"{char} is a lowercase letter.")
# Out:
# er is a lowercase letter.

# %%
#. Check if a triangle is valid given three side lengths
side1 = float(input("Enter the length of the first side: "))
side2 = float(input("Enter the length of the second side: "))
side3 = float(input("Enter the length of the third side: "))

if side1 + side2 > side3 and side1 + side3 > side2 and side2 + side3 > side1:
    print("The triangle is valid.")
else:
    print("The triangle is not valid.")
# Out:
# The triangle is valid.

# %% [markdown]
# MEDIUM LEVEL

# %%
# 1. Find the largest of three numbers
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))  
num3 = int(input("Enter the third number: "))

if num1 >= num2 and num1 >= num3:
    print(f"{num1} is the greatest.")
    
elif num2 >= num1 and num2 >= num3:
    print(f"{num2} is the greatest.")
else:
    print(f"{num3} is the greatest.")
# Out:
# 24 is the greatest.

# %%
# . Determine if a number is a prime number
num = int(input("Enter a number: "))
if num > 1:
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            print(f"{num} is not a prime number.")
            break
    else:
        print(f"{num} is a prime number.")  
else:
    print(f"{num} is not a prime number.")
# Out:
# 13 is a prime number.

# %%
# Check if a person is eligible for a driving license
age = int(input("enter age"))
pass_test = input("did you pass the driving test").lower()
if age >= 18 and pass_test == 'yes':
     print("Eligible for a driving license")
else:
 print("Not eligible")
# Out:
# Eligible for a driving license

# %%
# Determine if a triangle is equilateral, isosceles, or scalene
a = int(input("Enter first side: "))
b = int(input("Enter second side: "))
c = int(input("Enter third side: "))
if a == b == c:
 print("Equilateral Triangle")
elif a == b or b == c or a == c:
 print("Isosceles Triangle")
else:
 print("Scalene Triangle")
# Out:
# Scalene Triangle

# %%
# . Check if a number is a palindrome
num = input("Enter a number: ")
if num == num[::-1]:
 print("Palindrome")
else:
 print("Not a Palindrome")
# Out:
# Palindrome

# %%
# . Calculate electricity bill
units = int(input("Enter electricity units consumed: "))
if units <= 100:
 bill = units * 5
elif units <= 300:
 bill = (100 * 5) + (units - 100) * 10
else:
 bill = (100 * 5) + (200 * 10) + (units - 300) * 15
 print("Total Bill: ₹", bill)
# Out:
# Total Bill: ₹ 4510

# %%
# Find the grade of a student
marks = int(input("Enter marks: "))
if marks >= 90:
 print("Grade: A")
elif marks >= 80:
 print("Grade: B")
elif marks >= 70:
 print("Grade: C")
elif marks >= 60:
 print("Grade: D")
elif marks >= 40:
 print("Grade: E")
else:
 print("Grade: F (Fail)")
# Out:
# Grade: F (Fail)

# %%
# . Determine if a given date is valid
import calendar
day = int(input("Enter day: "))
month = int(input("Enter month: "))
year = int(input("Enter year: "))
if 1 <= month <= 12 and 1 <= day <= calendar.monthrange(year, month)[1]:
 print("Valid date")
else:
 print("Invalid date")
# Out:
# Invalid date

# %%
# Check if a given time is AM or PM
hour = int(input("Enter hour (24-hour format): "))
if hour < 12:
 print("AM")
else:
 print("PM")
# Out:
# AM

# %%
# . Check if a number is an Armstrong number
num = input("Enter a number: ")
power = len(num)
if sum(int(digit) ** power for digit in num) == int(num):
 print("Armstrong Number")
else:
 print("Not an Armstrong Number")
# Out:
# Armstrong Number

# %%
# . Determine the type of quadrilateral
a = int(input("Enter first side: "))
b = int(input("Enter second side: "))
c = int(input("Enter third side: "))
d = int(input("Enter fourth side: "))
if a == b == c == d:
 print("Square")
elif a == c and b == d:
 print("Rectangle")
else:
 print("Other Quadrilateral")
# Out:
# Other Quadrilateral

# %%
# . Implement a basic calculator
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
op = input("Enter operation (+, -, *, /): ")
if op == "+":
 print("Result:", a + b)
elif op == "-":
 print("Result:", a - b)
elif op == "*":
 print("Result:", a * b)
elif op == "/":
 print("Result:", a / b)
else:
 print("Invalid operation")
# Out:
# Result: 5.300000000000001

# %%
# Check if a bank account balance is sufficient for withdrawal
balance = float(input("Enter account balance: "))
withdraw = float(input("Enter withdrawal amount: "))
if balance >= withdraw:
 print("Withdrawal successful")
else:
 print("Insufficient funds")
# Out:
# Insufficient funds

# %%
#  Implement a temperature converter

temp = float(input("Enter temperature: "))
unit = input("Enter unit (C/F): ").upper()
if unit == "C":
 print("Fahrenheit:", (temp * 9/5) + 32)
elif unit == "F":
 print("Celsius:", (temp - 32) * 5/9)
else:
 print("Invalid unit")

# %%
#  Check if a number lies within a range (50-100)
num = int(input("Enter a number: "))
if 50 <= num <= 100:
 print("Within range")
else:
 print("Out of range")
# Out:
# Out of range

# %%
#  Check if a number is a power of 2
num = int(input("Enter a number: "))
if num > 0 and (num & (num - 1)) == 0:
 print("Power of 2")
else:
 print("Not a Power of 2")
# Out:
# Not a Power of 2

# %%
# Determine how many days a month has
month = int(input("Enter month (1-12): "))
year = int(input("Enter year: "))
days = [31, 28 + (1 if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0) else 0), 31,
30, 31, 30, 31, 31, 30, 31, 30, 31]
print("Days:", days[month - 1])

# %%
# Validate a password
import re
password = input("Enter password: ")
if len(password) >= 8 and re.search(r"[A-Za-z]", password) and re.search(r"\d", password):
 print("Valid Password")
else:
 print("Invalid Password")
# Out:
# Valid Password

# %%
num = 14

for i in range(2,num):
    if num % i == 0:
        print('Not prime Number')
        break
else:
    print('Prime Number')
