# %% [markdown]
# Tuple

# %%
tup1 = () #empty tuple

# %%
tuple2 = (1, 2, 3) #tuple with integers
print(tuple2)
# Out:
# (1, 2, 3)

# %%
tuple3 = ('a', 'b', 'c') #tuple with strings
print(tuple3)
# Out:
# ('a', 'b', 'c')

# %%
tuple4 = (2.34, 3.45, 4.56) #tuple with floats
print(tuple4)
# Out:
# (2.34, 3.45, 4.56)

# %%
tuple5 = ('aves', 1, (2, 3),(120, 130)) #tuple with mixed data types
print(tuple5)
# Out:
# ('aves', 1, (2, 3), (120, 130))

# %%
tuple6 = (100,'aves',13.2,[1, 2, 3],(4, 5, 6)) #tuple with mixed data types
print(tuple6)
# Out:
# (100, 'aves', 13.2, [1, 2, 3], (4, 5, 6))

# %%
len(tuple6) #length of tuple6
# Out:
# 5

# %% [markdown]
# TUPLE INDEXING

# %%
tuple2
# Out:
# (1, 2, 3)

# %%
tuple2[0] #accessing first element of tuple2
# Out:
# 1

# %%
tuple2[-1]#accessing third element of tuple5
# Out:
# 3

# %%
tuple5[3][0]
# Out:
# 120

# %%
tuple
# Out:
# tuple

# %% [markdown]
# Tuple Slicing

# %%
mytuple = ('one' , 'two' , 'three' , 'four' , 'five' , 'six' , 'seven' , 'eight')
print(mytuple)
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple[0:4] #slicing tuple from index 0 to 3
# Out:
# ('one', 'two', 'three', 'four')

# %%
mytuple[2:5] #slicing tuple from index 0 to 3
# Out:
# ('three', 'four', 'five')

# %%
mytuple[:3]
# Out:
# ('one', 'two', 'three')

# %%
mytuple[:4]
# Out:
# ('one', 'two', 'three', 'four')

# %%
mytuple[-3:]
# Out:
# ('six', 'seven', 'eight')

# %%
mytuple[-1]
# Out:
# 'eight'

# %%
tuple2[:]
# Out:
# (1, 2, 3)

# %% [markdown]
# Remove & change items

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
del mytuple[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 del mytuple[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
mytuple[0]=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 mytuple[0]=1
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuple4
# Out:
# (2.34, 3.45, 4.56)

# %%
del tuple4

# %%
tuple4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 tuple4
#
# NameError: name 'tuple4' is not defined

# %% [markdown]
# Loop through a tuple

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
for i in mytuple:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(mytuple):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %% [markdown]
# Count

# %%
mytuple1 =('one', 'two', 'three', 'four', 'one', 'one', 'two', 'three')
mytuple1
# Out:
# ('one', 'two', 'three', 'four', 'one', 'one', 'two', 'three')

# %%
mytuple1.count('one') #counting the number of times 'one' appears in mytuple1
# Out:
# 3

# %%
mytuple1.count('four') #counting the number of times 'four' appears in mytuple1
# Out:
# 1

# %% [markdown]
# Index position

# %%
mytuple1
# Out:
# ('one', 'two', 'three', 'four', 'one', 'one', 'two', 'three')

# %%
mytuple1.index('two') #finding the index of first occurrence of 'two' in mytuple1
# Out:
# 1

# %%
mytuple1.index('three') #finding the index of first occurrence of 'three' in mytuple1
# Out:
# 2

# %% [markdown]
# Sorting

# %%
mytuple2 = (43,67,99,12,6,90,67)
mytuple2
# Out:
# (43, 67, 99, 12, 6, 90, 67)

# %%
sorted(mytuple2) #sorting the elements of mytuple2 in ascending order
# Out:
# [6, 12, 43, 67, 67, 90, 99]

# %%
sorted(mytuple2,reverse=True) #sorting the elements of mytuple2 in descending order
# Out:
# [99, 90, 67, 67, 43, 12, 6]
