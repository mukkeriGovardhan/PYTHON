# %% [markdown]
# List

# %%
list =[]
print(type(list))
# Out:
# <class 'list'>

# %%
list2 = [1,2,3,4,5] # list of integers numbers
list3 = ["a","b","c","d","e"] # list of string characters
list4 = [10.5, 20.5, 30.5, 40.5, 50.5] # list of float numbers
list5 = [1, "a", 10.5, True] # list of mixed data types
list6 = [1, 2, 3, [4, 5, 6], [7, 8, 9]] # list of nested lists
list7 =  ['Asif', 25 ,[50, 100],[150, 90] , {'John' , 'David'}] # list of mixed data types with nested lists and sets
len(list7) # length of list6
# Out:
# 5

# %% [markdown]
# INDEXING

# %%
list7[3] # access first element of list7
# Out:
# [150, 90]

# %%
list7[2][1]
# Out:
# 100

# %%
list4[-1] # access last element of list4
# Out:
# 50.5

# %%
list6[-1]
# Out:
# [7, 8, 9]

# %%
list3
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
mylist = ['one' , 'two' , 'three' , 'four' , 'five' , 'six' , 'seven' , 'eight'] 
mylist[0:4] # access first four elements of mylist
# Out:
# ['one', 'two', 'three', 'four']

# %%
mylist[2:6] # access elements from index 2 to 5 of mylist
# Out:
# ['three', 'four', 'five', 'six']

# %%
mylist[:4]
# Out:
# ['one', 'two', 'three', 'four']

# %%
mylist[-3:] # access last three elements of mylist
# Out:
# ['six', 'seven', 'eight']

# %%
mylist[-2:] # access last two elements of mylist
# Out:
# ['seven', 'eight']

# %%
mylist[::-2] # access elements of mylist in reverse order with step of 2
# Out:
# ['eight', 'six', 'four', 'two']

# %%
mylist[2::]
# Out:
# ['three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist[::3]
# Out:
# ['one', 'four', 'seven']

# %%
mylist[::-3]
# Out:
# ['eight', 'five', 'two']

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# ADD , REMOVE AND CHANGE ITEMS

# %% [markdown]
# APPEND

# %%
mylist.append('nine') # add 'nine' to the end of mylist
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %% [markdown]
# INSERT

# %%
mylist.insert(0, 'zero') # insert 'zero' at index 0 of mylist
mylist
# Out:
# ['zero',
#  'one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine']

# %%
mylist.insert(1,'ONE') # insert 'ONE' at index 1 of mylist
mylist
# Out:
# ['zero',
#  'ONE',
#  'ONE',
#  'one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine']

# %% [markdown]
# REMOVE

# %%
mylist.remove('ONE') # remove item 'ONE' from mylist
mylist
# Out:
# ['zero',
#  'ONE',
#  'one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine']

# %% [markdown]
# POP

# %%
mylist.pop() # remove and return the last item of mylist
mylist
# Out:
# ['zero', 'ONE', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list2
# Out:
# [1, 2, 3, 4, 5]

# %%
list2.pop(4) # remove and return the item at index 4 of mylist
list2
# Out:
# [1, 2, 3, 4]

# %%
list2.pop(0) # remove and return the item at index 0 of mylist
list2
# Out:
# [2, 3, 4]

# %% [markdown]
# DELETE

# %%
del list2[0] # delete item at index 0 of list2
list2
# Out:
# [3, 4]

# %%
list4
# Out:
# [10.5, 20.5, 30.5, 40.5, 50.5]

# %%
#change value of the string 
list4[0] = 1 
list4[1] = 2 
list4[2] = 3
list4
# Out:
# [1, 2, 3, 40.5, 50.5]

# %%
list3
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# CLEAR

# %%
list3.clear() # clear all items from list3
list3
# Out:
# []

# %%
list3
# Out:
# []

# %% [markdown]
# COPY LIST

# %%
mylist1 = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine' ]
mylist1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1 = mylist
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
id(mylist1), id(mylist) # check if mylist1 and mylist refer to the same object in memory
# Out:
# (2468127181824, 2468127181824)

# %%
mylist[0]=1
mylist
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %% [markdown]
# JOIN LIST

# %%
list1 = ['one', 'two', 'three', 'four'] 
list2 = ['five', 'six', 'seven', 'eight'] 
list3 = list1 + list2 # concatenate list1 and list2 to create a new list list3
list3
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.extend(list2) # extend list1 by adding all elements of list2 to the end of list1
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
#     LIST MEMBERSHIP

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
'one' in list1 # check if 'one' is in list1
# Out:
# True

# %%
'wen' in list1 # check if 'wen' is in list1
# Out:
# False

# %%
if 'three' in list1: # Check if 'three' exist in the list 
   print('Three is present in the list') 
else: 
    print('Three is not present in the list')
# Out:
# Three is present in the list

# %% [markdown]
# REverse & SORT LIST

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.reverse() # reverse the order of elements in list1
list1
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
list1 = list1[::-1] # Reverse the list using slicing
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# SORT

# %%
list7
# Out:
# ['Asif', 25, [50, 100], [150, 90], {'David', 'John'}]

# %%
list7.sort() # sort the elements of list7 in ascending order
list7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 list7.sort() # sort the elements of list7 in ascending order
#       2 list7
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
list2
# Out:
# ['five', 'six', 'seven', 'eight']

# %%
list2.sort() # sort the elements of list2 in ascending order
list2
# Out:
# ['eight', 'five', 'seven', 'six']

# %%
list1.sort() # sort the elements of list1 in ascending order
list1
# Out:
# ['eight', 'five', 'four', 'one', 'seven', 'six', 'three', 'two']

# %% [markdown]
#         LOOP THROUGH A LIST

# %%
for i in list1: # iterate through each element in list1 and print it
    print(i)
# Out:
# eight
# five
# four
# one
# seven
# six
# three
# two

# %%
for i in enumerate(list1): # iterate through each element in list1 and print its index and value
    print(i)
# Out:
# (0, 'eight')
# (1, 'five')
# (2, 'four')
# (3, 'one')
# (4, 'seven')
# (5, 'six')
# (6, 'three')
# (7, 'two')

# %%
list1.count('one') # count the number of occurrences of 'one' in list1
# Out:
# 1

# %%
list7.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 list7.count()
#
# TypeError: list.count() takes exactly one argument (0 given)

# %% [markdown]
# ALL() method

# %%
list1.sort(reverse=True) # sort the elements of list1 in descending order
list1
# Out:
# ['two', 'three', 'six', 'seven', 'one', 'four', 'five', 'eight']

# %%
list1 = [1,2,3,4] 
all(list1) # check if all elements of list1 are true (non-zero)
# Out:
# True

# %%
list7[1] = 0 # change the second element of list7 to 0
all(list7) # check if all elements of list7 are true (non-zero)
# Out:
# False

# %%
all(list7) # check if all elements of list7 are true (non-zero)
# Out:
# True

# %% [markdown]
# ANY()

# %%
any(list7) # check if any element of list7 is true (non-zero)
# Out:
# True

# %%
any(list1) # check if any element of list1 is true (non-zero)
# Out:
# True
