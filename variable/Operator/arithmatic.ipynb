# %%
a = 10
b = 20
print(a+b)
print(a*b)
print(a/b)      
print(a//b)     # floor division
print(a%b)      # modulus   
print(a**b)     # exponentiation
print(a-b)      # subtraction
# Out:
# 30
# 200
# 0.5
# 0
# 10
# 100000000000000000000
# -10
